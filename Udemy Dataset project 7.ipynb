# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\DELL\Downloads\7. Udemy Courses.csv')

# %%
df
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# ...         ...                                                ...      ...
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %% [markdown]
# # 1. What are the diffrent subjects for which Udemy is offering courses?

# %%
df.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
df.subject.unique()
# Out:
# array(['Musical Instruments', 'Business Finance', 'Graphic Design',
#        'Web Development'], dtype=object)

# %% [markdown]
# # 2. Which subject has the maximum number of courses.

# %%
pd.DataFrame(df['subject'].value_counts())
# Out:
#                      subject
# Web Development         1200
# Business Finance        1199
# Musical Instruments      680
# Graphic Design           603

# %% [markdown]
# # 3. Show all the courses which are Free of Cost.

# %%
df[df['is_paid'] == False]
# Out:
#       course_id                                       course_title  is_paid  \
# 41       286070        5 lecciones que todo guitarrista debe tomar    False
# 49       696630  7 Ways A Beginner Guitarist Can Sound Better, ...    False
# 57       955914  A beginner`s guide to fingerpicking and strumm...    False
# 67       270976                             A how to guide in HTML    False
# 74      1214144  ¡Triunfar en La Bolsa de Valores No Requiere d...    False
# ...         ...                                                ...      ...
# 3620     552598  WordPress in under an hour - Create/manage you...    False
# 3638    1068590                     Wordpress Website Mastery 2017    False
# 3652     752706  Write quicker HTML5 and CSS 3; productivity ha...    False
# 3674    1257976  Your First 10 Guitar Lessons - Learn how to pl...    False
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
#
# ...

# %% [markdown]
# # 4. Show all the courses which are Paid.

# %%
df1 =df[df['is_paid'] == True]

# %%
df2 = pd.DataFrame(df1['course_title'])

# %%
df2.style.set_caption('Paid Courses')
# Out:
# <style  type="text/css" >
# </style><table id="T_e2bb9_" ><caption>Paid Courses</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >course_title</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e2bb9_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e2bb9_row0_col0" class="data row0 col0" >#1 Piano Hand Coordination: Play 10th Ballad in Eb Key songs</td>
#             </tr>
#             <tr>
#                         <th id="T_e2bb9_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e2bb9_row1_col0" class="data row1 col0" >#10 Hand Coordination - Transfer Chord Ballad 9 - C & Bb Key</td>
#             </tr>
#             <tr>
#                         <th id="T_e2bb9_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %% [markdown]
# # Which are Top Selling Courses?

# %%
df.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %%
pd.DataFrame(df.groupby('course_title').sum().num_subscribers).sort_values(by = 'num_subscribers', ascending = False)
# Out:
#                                                     num_subscribers
# course_title
# Learn HTML5 Programming From Scratch                         268923
# Coding for Entrepreneurs Basic                               161029
# The Web Developer Bootcamp                                   121584
# Build Your First Website in 1 Week with HTML5 a...           120291
# The Complete Web Developer Course 2.0                        114512
# ...                                                             ...
# Learn to Play Piano Like a Pro - Easy Piano Cou...                0
# Learn to Play Sweet Child of Mine                                 0
# Learn to create Text fire effect in Adobe Photo...                0
# Tune that Sour Note on Your Piano                                 0
# How to Invest Using ETFs from Former Wall Stree...                0
#
# [3667 rows x 1 columns]

# %% [markdown]
# # Which are Least Selling Courses?

# %%
pd.DataFrame(df.groupby('course_title').sum().num_subscribers).sort_values(by = 'num_subscribers', ascending = True)
# Out:
#                                                     num_subscribers
# course_title
# Learn to trade using technical analysis                           0
# Photoshop: Creando elemental de aire                              0
# Building a Balanced Scorecard                                     0
# Basic Bookkeeping                                                 0
# Accounting - The 6 most important rules you mus...                0
# ...                                                             ...
# The Complete Web Developer Course 2.0                        114512
# Build Your First Website in 1 Week with HTML5 a...           120291
# The Web Developer Bootcamp                                   121584
# Coding for Entrepreneurs Basic                               161029
# Learn HTML5 Programming From Scratch                         268923
#
# [3667 rows x 1 columns]

# %% [markdown]
# # 7. Show all courses of Graphic Design where the price is below 100?

# %%
df[(df.subject == 'Graphic Design') & (df.price < '100' )]
# Out:
# Empty DataFrame
# Columns: [course_id, course_title, is_paid, price, num_subscribers, num_reviews, num_lectures, level, content_duration, published_timestamp, subject]
# Index: []

# %% [markdown]
# # 8. List out all the courses that are related with "Python".

# %%
df[df.course_title.str.contains('Python')]
# Out:
#       course_id                                       course_title  is_paid  \
# 216      599504  Advanced Scalable Python Web Development Using...     True
# 777       47963  Coding for Entrepreneurs: Learn Python, Django...     True
# 814      631128  Complete Python Web Course: Build 8 Python Web...     True
# 842      186096  Core: A Web App Reference Guide for Django, Py...     True
# 1400     394832  Fun and creative web engineering with Python a...    False
# 1932    1038538            Introduction to QGIS Python Programming     True
# 1969     902888          Investment Portfolio Analysis with Python     True
# 2294     391546        Learn Python and Django: Payment Processing     True
# 2295    1063722            Learn Python Django - A Hands-On Course     True
# 2341     546848  Learn to code in Python and learn Adobe Photos...     True
# 2906     368340    Professional Python Web Development Using Flask     True
# ...

# %% [markdown]
# # 9. What are courses that published in year 2015?

# %%
df.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
df['published_timestamp'].dtype
# Out:
# dtype('O')

# %%
df['published_timestamp'] = pd.to_datetime(df.published_timestamp)

# %%
df['published_timestamp'].dtype
# Out:
# datetime64[ns, UTC]

# %%
df['data year'] = df['published_timestamp'].dt.year

# %%
df
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# ...         ...                                                ...      ...
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %%
df[df['data year'] == 2015]
# Out:
#       course_id                                       course_title  is_paid  \
# 10       591880  1 - Concepts of Statistics For Beginners Step ...     True
# 16       302450        10 Numbers Every Business Owner Should Know     True
# 19       384928  101 Blues riffs - learn how the harmonica supe...     True
# 23       550842  16 Guitar Chords to Jam With - (Beginner - Int...     True
# 26       486240      2 Easy Steps To Investment And Avoiding Traps     True
# ...         ...                                                ...      ...
# 3675     551170                         Your First Course on Piano     True
# 3676     498488  Your First Successful Forex Trades - With Case...     True
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
#
# ...

# %% [markdown]
# # 10. What are the Max.Number of subscribers for Each level of courses?

# %%
pd.DataFrame(df.groupby('level').num_subscribers.max())
# Out:
#                     num_subscribers
# level
# All Levels                   268923
# Beginner Level               161029
# Expert Level                   5172
# Intermediate Level            29167
